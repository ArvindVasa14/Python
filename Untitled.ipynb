# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv(r'C:\Users\Arvind Vasa\OneDrive\Desktop\DL _ NLP By Sundaram- 6th Feb 2023\22nd Feb 2023\diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.pivot_table(index= 'SkinThickness', columns='Age', values='Pregnancies')
# Out:
# Age                  21        22        23        24        25        26  \
# SkinThickness
# 0              1.333333  2.833333  2.166667  3.000000  1.700000  2.285714
# 7                   NaN       NaN       NaN       NaN       NaN       NaN
# 8              1.000000       NaN       NaN       NaN       NaN       NaN
# 10             1.000000  1.000000       NaN       NaN  3.000000       NaN
# 11                  NaN  1.500000       NaN       NaN       NaN       NaN
# 12                  NaN       NaN       NaN  1.000000       NaN       NaN
# 13             0.000000  2.000000  1.750000  2.000000  1.000000  2.000000
# 14             0.500000  1.000000       NaN  2.000000       NaN       NaN
# 15             2.333333  0.500000       NaN  3.000000  2.000000  1.000000
# 16             0.000000  3.000000       NaN  1.000000  2.000000       NaN
# 17             0.666667  1.666667  2.000000       NaN       NaN  4.000000
# ...
